# %% [markdown]
# # 02 - Probability of Default (PD) Modeling
#
# - Logistic regression, XGBoost, benchmarking
# - Train/test split, cross-validation, hyperparameter tuning
# - Model interpretability (coefficients, SHAP)

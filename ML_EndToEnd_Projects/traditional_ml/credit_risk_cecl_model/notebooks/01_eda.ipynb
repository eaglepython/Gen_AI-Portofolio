# %% [markdown]
# # 01 - Exploratory Data Analysis (EDA)
#
# - Load raw CIB loan/borrower data
# - Data quality checks, missing values, outlier detection
# - Financial statement parsing and feature engineering
# - Portfolio risk trends and exposure analysis
